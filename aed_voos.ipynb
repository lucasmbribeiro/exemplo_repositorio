# Codigo.Justificativa                    NaN                    NaN
# Aeroporto.Origem                Afonso Pena          Salgado Filho
# Cidade.Origem          Sao Jose Dos Pinhais           Porto Alegre
# Estado.Origem                            PR                     RS
# Pais.Origem                          Brasil                 Brasil
# Aeroporto.Destino             Salgado Filho                  Miami
# Cidade.Destino                 Porto Alegre                  Miami
# Estado.Destino                           RS                    N/I
# Pais.Destino                         Brasil         Estados Unidos
# LongDest                         -51.175381             -80.287046
# LatDest                          -29.993473              25.795865
# LongOrig                         -49.172481             -51.175381
# LatOrig                          -25.532713             -29.993473
#
#                                     2        \
# Voos                              AAL - 203
# Companhia.Aerea       AMERICAN AIRLINES INC
# Codigo.Tipo.Linha             Internacional
# Partida.Prevista       2016-01-29T12:13:00Z
# Partida.Real           2016-01-29T12:13:00Z
# Chegada.Prevista       2016-01-29T21:30:00Z
# Chegada.Real           2016-01-29T21:30:00Z
# Situacao.Voo                      Realizado
# Codigo.Justificativa                    NaN
# Aeroporto.Origem              Salgado Filho
# Cidade.Origem                  Porto Alegre
# Estado.Origem                            RS
# Pais.Origem                          Brasil
# Aeroporto.Destino                     Miami
# Cidade.Destino                        Miami
# Estado.Destino                          N/I
# Pais.Destino                 Estados Unidos
# LongDest                         -80.287046
# LatDest                           25.795865
# LongOrig                         -51.175381
# LatOrig                          -29.993473
#
#                                                         3        \
# Voos                                                  AAL - 203
# Companhia.Aerea                           AMERICAN AIRLINES INC
# Codigo.Tipo.Linha                                 Internacional
# Partida.Prevista                           2016-01-19T12:13:00Z
# Partida.Real                               2016-01-18T12:03:00Z
# Chegada.Prevista                           2016-01-19T21:30:00Z
# Chegada.Real                               2016-01-18T20:41:00Z
# Situacao.Voo                                          Realizado
# Codigo.Justificativa  LIBERACAO SERV. TRAFEGO AEREO/ANTECIPACAO
# Aeroporto.Origem                                  Salgado Filho
# Cidade.Origem                                      Porto Alegre
# Estado.Origem                                                RS
# Pais.Origem                                              Brasil
# Aeroporto.Destino                                         Miami
# Cidade.Destino                                            Miami
# Estado.Destino                                              N/I
# Pais.Destino                                     Estados Unidos
# LongDest                                             -80.287046
# LatDest                                               25.795865
# LongOrig                                             -51.175381
# LatOrig                                              -29.993473
#
#                                     4                      5        \
# Voos                              AAL - 203              AAL - 203
# Companhia.Aerea       AMERICAN AIRLINES INC  AMERICAN AIRLINES INC
# Codigo.Tipo.Linha             Internacional          Internacional
# Partida.Prevista       2016-01-30T12:13:00Z   2016-01-03T23:05:00Z
# Partida.Real           2016-01-30T12:13:00Z   2016-01-03T23:05:00Z
# Chegada.Prevista       2016-01-30T21:30:00Z   2016-01-04T07:50:00Z
# Chegada.Real           2016-01-30T21:30:00Z   2016-01-04T07:50:00Z
# Situacao.Voo                      Realizado              Realizado
# Codigo.Justificativa                    NaN                    NaN
# Aeroporto.Origem              Salgado Filho                  Miami
# Cidade.Origem                  Porto Alegre                  Miami
# Estado.Origem                            RS                    N/I
# Pais.Origem                          Brasil         Estados Unidos
# Aeroporto.Destino                     Miami            Afonso Pena
columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542519 entries, 0 to 2542518
# Data columns (total 21 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Voos                  object
#  1   Companhia.Aerea       object
#  2   Codigo.Tipo.Linha     object
#  3   Partida.Prevista      object
#  4   Partida.Real          object
#  5   Chegada.Prevista      object
#  6   Chegada.Real          object
#  7   Situacao.Voo          object
#  8   Codigo.Justificativa  object
#  9   Aeroporto.Origem      object
#  10  Cidade.Origem         object
#  11  Estado.Origem         object
#  12  Pais.Origem           object
#  13  Aeroporto.Destino     object
#  14  Cidade.Destino        object
#  15  Estado.Destino        object
#  16  Pais.Destino          object
#  17  LongDest              float64
#  18  LatDest               float64
#  19  LongOrig              float64
#  20  LatOrig               float64
# dtypes: float64(4), object(17)
# memory usage: 407.4+ MB

# %% [markdown]
# ***
#
# ## Ajuste da Estrutura do DataFrame

# %% [markdown]
# ### Ajuste do nome das coluna

# %%
df.columns
# Out:
# Index(['Voos', 'Companhia.Aerea', 'Codigo.Tipo.Linha', 'Partida.Prevista',
#        'Partida.Real', 'Chegada.Prevista', 'Chegada.Real', 'Situacao.Voo',
#        'Codigo.Justificativa', 'Aeroporto.Origem', 'Cidade.Origem',
#        'Estado.Origem', 'Pais.Origem', 'Aeroporto.Destino', 'Cidade.Destino',
#        'Estado.Destino', 'Pais.Destino', 'LongDest', 'LatDest', 'LongOrig',
#        'LatOrig'],
#       dtype='object')

# %%
df.columns = [
    'voos', 'companhia', 'tp_voo', 'dt_partida_prev',
    'dt_partida_real', 'dt_chegada_prev', 'dt_chegada_real', 'situacao',
    'justificativa', 'aeroporto_origem', 'cidade_origem','uf_origem',
    'pais_origem', 'aeroporto_destino', 'cidade_destino','uf_destino',
    'pais_destino', 'long_destino', 'lat_destino', 'long_origem','lat_origem'
]

# %%
df.columns
# Out:
# Index(['voos', 'companhia', 'tp_voo', 'dt_partida_prev', 'dt_partida_real',
#        'dt_chegada_prev', 'dt_chegada_real', 'situacao', 'justificativa',
#        'aeroporto_origem', 'cidade_origem', 'uf_origem', 'pais_origem',
#        'aeroporto_destino', 'cidade_destino', 'uf_destino', 'pais_destino',
#        'long_destino', 'lat_destino', 'long_origem', 'lat_origem'],
#       dtype='object')

# %% [markdown]
# ### Alterando o tipo das colunas de data

# %%
# ANTES: '2016-01-30T08:58:00Z'
df['dt_partida_prev'][0]
# Out:
# '2016-01-30T08:58:00Z'

# %%
# DEPOIS: 2016-01-30 08:58
pd.to_datetime(df['dt_partida_prev'][0])
# Out:
# Timestamp('2016-01-30 08:58:00+0000', tz='UTC')

# %%
pd.to_datetime(df['dt_partida_prev'][0]).strftime('%Y-%m-%d %H:%M')
# Out:
# '2016-01-30 08:58'

# %%
df['dt_partida_prev'] = pd.to_datetime(df['dt_partida_prev']).dt.strftime('%Y-%m-%d %H:%M')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542519 entries, 0 to 2542518
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   voos               object
#  1   companhia          object
#  2   tp_voo             object
#  3   dt_partida_prev    object
#  4   dt_partida_real    object
#  5   dt_chegada_prev    object
#  6   dt_chegada_real    object
#  7   situacao           object
#  8   justificativa      object
#  9   aeroporto_origem   object
#  10  cidade_origem      object
#  11  uf_origem          object
#  12  pais_origem        object
#  13  aeroporto_destino  object
#  14  cidade_destino     object
#  15  uf_destino         object
#  16  pais_destino       object
#  17  long_destino       float64
#  18  lat_destino        float64
#  19  long_origem        float64
#  20  lat_origem         float64
# dtypes: float64(4), object(17)
# memory usage: 407.4+ MB

# %%
# dt_partida_real
df['dt_partida_real'] = pd.to_datetime(df['dt_partida_real']).dt.strftime('%Y-%m-%d %H:%M')

# dt_chegada_prev 
df['dt_chegada_prev'] = pd.to_datetime(df['dt_chegada_prev']).dt.strftime('%Y-%m-%d %H:%M')

# dt_chegada_real
df['dt_chegada_real'] = pd.to_datetime(df['dt_chegada_real']).dt.strftime('%Y-%m-%d %H:%M')

# %%
# Alterar o data type das colunas para DateTime

# dt_partida_prev
df['dt_partida_prev'] = df['dt_partida_prev'].astype('datetime64[ns]')

# dt_partida_real
df['dt_partida_real'] = df['dt_partida_real'].astype('datetime64[ns]')

# dt_chegada_prev 
df['dt_chegada_prev'] = df['dt_chegada_prev'].astype('datetime64[ns]')

# dt_chegada_real
df['dt_chegada_real'] = df['dt_chegada_real'].astype('datetime64[ns]')

# %% [markdown]
# ### Alterando a coluna situacao

# %%
df['situacao'].nunique()
# Out:
# 2

# %%
df['situacao'].unique()
# Out:
# array(['Realizado', 'Cancelado'], dtype=object)

# %%
# VERIFICAR 
# Se a coluna situacao for igual a Realizado
### >>> Atribui 1 como valor
### >>> Se não, atribui 0 como valor

df['situacao']
# Out:
# 0          Realizado
# 1          Realizado
# 2          Realizado
# 3          Realizado
# 4          Realizado
#              ...
# 2542514    Realizado
# 2542515    Realizado
# 2542516    Realizado
# 2542517    Realizado
# 2542518    Realizado
# Name: situacao, Length: 2542519, dtype: object

# %%
df['situacao'] = np.where( df['situacao'] == 'Realizado', 1, 0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542519 entries, 0 to 2542518
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   voos               object
#  1   companhia          object
#  2   tp_voo             object
#  3   dt_partida_prev    datetime64[ns]
#  4   dt_partida_real    datetime64[ns]
#  5   dt_chegada_prev    datetime64[ns]
#  6   dt_chegada_real    datetime64[ns]
#  7   situacao           int32
#  8   justificativa      object
#  9   aeroporto_origem   object
#  10  cidade_origem      object
#  11  uf_origem          object
#  12  pais_origem        object
#  13  aeroporto_destino  object
#  14  cidade_destino     object
#  15  uf_destino         object
#  16  pais_destino       object
#  17  long_destino       float64
#  18  lat_destino        float64
#  19  long_origem        float64
#  20  lat_origem         float64
# dtypes: datetime64[ns](4), float64(4), int32(1), object(12)
# memory usage: 397.7+ MB

# %% [markdown]
# ## Tratando as colunas com registros nulos

# %%
df.isna().sum()
# Out:
# voos                       0
# companhia                  0
# tp_voo                     0
# dt_partida_prev            0
# dt_partida_real       289196
# dt_chegada_prev            0
# dt_chegada_real       289196
# situacao                   0
# justificativa        1510212
# aeroporto_origem           0
# cidade_origem              0
# uf_origem                  0
# pais_origem                0
# aeroporto_destino          0
# cidade_destino             0
# uf_destino                 0
# pais_destino               0
# long_destino               0
# lat_destino                0
# long_origem                0
# lat_origem                 0
# dtype: int64

# %%
df[ (df['dt_chegada_real'].isnull() == True ) & (df['situacao'] == 0) ]
# Out:
#                voos              companhia         tp_voo     dt_partida_prev  \
# 111       AAL - 213  AMERICAN AIRLINES INC  Internacional 2016-01-18 00:29:00
# 115       AAL - 213  AMERICAN AIRLINES INC  Internacional 2016-01-17 00:29:00
# 149       AAL - 214  AMERICAN AIRLINES INC  Internacional 2016-01-15 23:59:00
# 158       AAL - 229  AMERICAN AIRLINES INC  Internacional 2016-01-21 00:34:00
# 162       AAL - 229  AMERICAN AIRLINES INC  Internacional 2016-01-05 00:34:00
# ...             ...                    ...            ...                 ...
# 2541976  TAM - 8113                    TAM  Internacional 2015-11-28 20:45:00
# 2541979  TAM - 8113                    TAM  Internacional 2015-11-10 20:45:00
# 2541981  TAM - 8113                    TAM  Internacional 2015-11-27 20:45:00
# 2541993  TAM - 8113                    TAM  Internacional 2015-11-19 20:45:00
# 2542352  TAM - 8112                    TAM  Internacional 2015-12-26 23:25:00
#
#         dt_partida_real     dt_chegada_prev dt_chegada_real  situacao  \
# 111                 NaT 2016-01-18 07:56:00             NaT         0
# 115                 NaT 2016-01-17 07:56:00             NaT         0
# 149                 NaT 2016-01-16 07:46:00             NaT         0
# 158                 NaT 2016-01-21 08:44:00             NaT         0
# 162                 NaT 2016-01-05 08:44:00             NaT         0
# ...                 ...                 ...             ...       ...
# 2541976             NaT 2015-11-29 06:25:00             NaT         0
# 2541979             NaT 2015-11-11 06:25:00             NaT         0
# 2541981             NaT 2015-11-28 06:25:00             NaT         0
# 2541993             NaT 2015-11-20 06:25:00             NaT         0
# 2542352             NaT 2015-12-27 09:15:00             NaT         0
#
#                                             justificativa  \
# 111      CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 115      CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 149      CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 158      CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 162      CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# ...                                                   ...
# 2541976  CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 2541979  CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 2541981  CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 2541993  CANCELAMENTO POR MOTIVOS TECNICOS - OPERACIONAIS
# 2542352    CANCELAMENTO - AEROPORTO ORIGEM ABAIXO LIMITES
#
#                                     aeroporto_origem  ... uf_origem  \
# 111                                            Miami  ...       N/I
# 115                                            Miami  ...       N/I
# 149                  Presidente Juscelino Kubitschek  ...        DF
# 158                                            Miami  ...       N/I
# 162                                            Miami  ...       N/I
# ...                                              ...  ...       ...
# 2541976                                       Mexico  ...       N/I
# 2541979                                       Mexico  ...       N/I
# 2541981                                       Mexico  ...       N/I
# 2541993                                       Mexico  ...       N/I
# 2542352  Guarulhos - Governador Andre Franco Montoro  ...        SP
#
#             pais_origem                            aeroporto_destino  \
# 111      Estados Unidos              Presidente Juscelino Kubitschek
# 115      Estados Unidos              Presidente Juscelino Kubitschek
# 149              Brasil                                        Miami
# 158      Estados Unidos              Deputado Luis Eduardo Magalhaes
# 162      Estados Unidos              Deputado Luis Eduardo Magalhaes
# ...                 ...                                          ...
# 2541976          Mexico  Guarulhos - Governador Andre Franco Montoro
# 2541979          Mexico  Guarulhos - Governador Andre Franco Montoro
# 2541981          Mexico  Guarulhos - Governador Andre Franco Montoro
# 2541993          Mexico  Guarulhos - Governador Andre Franco Montoro
# 2542352          Brasil                                       Mexico
#
#         cidade_destino uf_destino    pais_destino long_destino  lat_destino  \
# 111           Brasilia         DF          Brasil   -47.917235   -15.869737
# 115           Brasilia         DF          Brasil   -47.917235   -15.869737
# 149              Miami        N/I  Estados Unidos   -80.287046    25.795865
# 158           Salvador         BA          Brasil   -38.331241   -12.911098
# 162           Salvador         BA          Brasil   -38.331241   -12.911098
# ...                ...        ...             ...          ...          ...
# 2541976      Guarulhos         SP          Brasil   -46.478126   -23.434553
# 2541979      Guarulhos         SP          Brasil   -46.478126   -23.434553
# 2541981      Guarulhos         SP          Brasil   -46.478126   -23.434553
# 2541993      Guarulhos         SP          Brasil   -46.478126   -23.434553
# 2542352         Mexico        N/I          Mexico   -99.071908    19.436076
#
#          long_origem  lat_origem
# 111       -80.287046   25.795865
# 115       -80.287046   25.795865
# 149       -47.917235  -15.869737
# 158       -80.287046   25.795865
# 162       -80.287046   25.795865
# ...              ...         ...
# 2541976   -99.071908   19.436076
# 2541979   -99.071908   19.436076
# 2541981   -99.071908   19.436076
# 2541993   -99.071908   19.436076
# 2542352   -46.478126  -23.434553
#
# [289196 rows x 21 columns]

# %%
# !pip install pandas_profiling

# %% [markdown]
# from pandas_profiling import ProfileReport

# %% [markdown]
# profile = ProfileReport(
#     df.sample(100000),                            # Pega 100k registros aleatórios do DF
#     title = 'AED - Voos do Brasil',               # Titulo que irá aparecer no documento HTML
#     html = { 'style': {'full_width': True} },     # Queremos que o HTML tenha o stilo para o tamanho real
#     explorative = True,                           # Habilita a opção de exploração
#     dark_mode = True                              # A cor mais escura
#
# )

# %% [markdown]
# profile.to_file('df_voos_profile_dark_mode.html')

# %% [markdown]
# ***
#
# # Vídeo 03 -  Explorando o dataset

# %% [markdown]
# ### Quantidade de voos por Ano e Mês

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542519 entries, 0 to 2542518
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   voos               object
#  1   companhia          object
#  2   tp_voo             object
#  3   dt_partida_prev    datetime64[ns]
#  4   dt_partida_real    datetime64[ns]
#  5   dt_chegada_prev    datetime64[ns]
#  6   dt_chegada_real    datetime64[ns]
#  7   situacao           int32
#  8   justificativa      object
#  9   aeroporto_origem   object
#  10  cidade_origem      object
#  11  uf_origem          object
#  12  pais_origem        object
#  13  aeroporto_destino  object
#  14  cidade_destino     object
#  15  uf_destino         object
#  16  pais_destino       object
#  17  long_destino       float64
#  18  lat_destino        float64
#  19  long_origem        float64
#  20  lat_origem         float64
# dtypes: datetime64[ns](4), float64(4), int32(1), object(12)
# memory usage: 397.7+ MB

# %%
df.groupby( df['dt_partida_prev'].dt.year ).agg({'voos': np.count_nonzero}).reset_index()
# Out:
#    dt_partida_prev     voos
# 0             2015  1082384
# 1             2016   937671
# 2             2017   522464

# %%
sns.set_style("darkgrid")

ax = sns.barplot(
    data = df.groupby(df['dt_partida_prev'].dt.year).agg({'voos': np.count_nonzero}).reset_index(),
    x = 'dt_partida_prev',
    y = 'voos',
    alpha=.8
)

ax.figure.set_size_inches(12,6)
ax.set_title("Quantidade de Voos x Ano - Data Prevista de Partida")
ax.set_xlabel("Ano")
ax.set_ylabel("Quantidade de Voos")

plt.ticklabel_format(style='plain', axis='y')

ax
# Out:
# <AxesSubplot:title={'center':'Quantidade de Voos x Ano - Data Prevista de Partida'}, xlabel='Ano', ylabel='Quantidade de Voos'>

# %%
df.assign(ano=df['dt_partida_prev'].dt.year, mes=df['dt_partida_prev'].dt.month
         ).groupby(['ano', 'mes']).agg({'voos': np.count_nonzero}).reset_index().head(5)
# Out:
#     ano  mes   voos
# 0  2015    1  93081
# 1  2015    2  84588
# 2  2015    3  92636
# 3  2015    4  88981
# 4  2015    5  90564

# %%
ax = sns.barplot(
    data = df.assign(ano=df['dt_partida_prev'].dt.year, mes=df['dt_partida_prev'].dt.month
         ).groupby(['ano', 'mes']).agg({'voos': np.count_nonzero}).reset_index(),
    x = 'mes',
    hue = 'ano',
    y = 'voos',
    alpha=.8,
)

ax.figure.set_size_inches(18,6)
ax.set_title("Quantidade de Voos x Ano - Data Prevista de Partida")
ax.set_xlabel("Ano")
ax.set_ylabel("Quantidade de Voos")

plt.legend(bbox_to_anchor = (1.0, 0.6))

ax
# Out:
# <AxesSubplot:title={'center':'Quantidade de Voos x Ano - Data Prevista de Partida'}, xlabel='Ano', ylabel='Quantidade de Voos'>

# %%
df.assign(
    ano=df['dt_partida_prev'].dt.year, 
    mes=df['dt_partida_prev'].dt.strftime('%b'),
    mes_ordem = df['dt_partida_prev'].dt.month
         ).groupby(['ano', 'mes', 'mes_ordem']).agg({'voos': np.count_nonzero}).reset_index().sort_values(by='mes_ordem')



ax = sns.barplot(
    data = df.assign(
    ano=df['dt_partida_prev'].dt.year, 
    mes=df['dt_partida_prev'].dt.strftime('%b'),
    mes_ordem = df['dt_partida_prev'].dt.month
         ).groupby(['ano', 'mes', 'mes_ordem']).agg({'voos': np.count_nonzero}).reset_index().sort_values(by='mes_ordem'),
    x = 'mes',
    hue = 'ano',
    y = 'voos',
    alpha=.8,
)

ax.figure.set_size_inches(18,6)
ax.set_title("Quantidade de Voos x Ano - Data Prevista de Partida")
ax.set_xlabel("Ano")
ax.set_ylabel("Quantidade de Voos")

plt.legend(bbox_to_anchor = (1.0, 0.6))

ax
# Out:
# <AxesSubplot:title={'center':'Quantidade de Voos x Ano - Data Prevista de Partida'}, xlabel='Ano', ylabel='Quantidade de Voos'>

# %%
df_2 = df.loc[:, ['dt_partida_prev', 'voos']]

df_2.head()
# Out:
#       dt_partida_prev       voos
# 0 2016-01-30 08:58:00  AAL - 203
# 1 2016-01-13 12:13:00  AAL - 203
# 2 2016-01-29 12:13:00  AAL - 203
# 3 2016-01-19 12:13:00  AAL - 203
# 4 2016-01-30 12:13:00  AAL - 203

# %%
df_2['dt'] = df_2['dt_partida_prev'].dt.strftime('%Y-%m-%d').astype('datetime64[ns]')

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542519 entries, 0 to 2542518
# Data columns (total 3 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   dt_partida_prev  datetime64[ns]
#  1   voos             object
#  2   dt               datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 58.2+ MB

# %%
df_2.head()
# Out:
#       dt_partida_prev       voos         dt
# 0 2016-01-30 08:58:00  AAL - 203 2016-01-30
# 1 2016-01-13 12:13:00  AAL - 203 2016-01-13
# 2 2016-01-29 12:13:00  AAL - 203 2016-01-29
# 3 2016-01-19 12:13:00  AAL - 203 2016-01-19
# 4 2016-01-30 12:13:00  AAL - 203 2016-01-30

# %%
ax = sns.lineplot(
    data = df_2.groupby('dt').agg({'voos': np.count_nonzero}).reset_index(),
    x = 'dt',
    y = 'voos'
)

ax.figure.set_size_inches(18,6)

# %%
ax = sns.lineplot(
    data = df_2[ (df_2['dt'] >= '2015-01-01') &  (df_2['dt'] <= '2015-01-31')
               ].groupby('dt').agg({'voos': np.count_nonzero}).reset_index(),
    x = 'dt',
    y = 'voos',
    marker = 'o'
)

ax.figure.set_size_inches(18,6)

# %%
df.assign(ano=df['dt_partida_prev'].dt.year, mes=df['dt_partida_prev'].dt.month
         ).groupby(['ano', 'mes']).agg({'voos': np.count_nonzero}).reset_index()


ax = sns.lineplot(
    data = df.assign(ano=df['dt_partida_prev'].dt.year, mes=df['dt_partida_prev'].dt.month
         ).groupby(['ano', 'mes']).agg({'voos': np.count_nonzero}).reset_index(),
    x = 'mes',
    y = 'voos',
    hue = 'ano',
    marker = 'o'
)

ax.figure.set_size_inches(18,6)

# %% [markdown]
# ***
#
# # Vídeo 04 - Explorando as dimensões

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542519 entries, 0 to 2542518
# Data columns (total 21 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   voos               object
#  1   companhia          object
#  2   tp_voo             object
#  3   dt_partida_prev    datetime64[ns]
#  4   dt_partida_real    datetime64[ns]
#  5   dt_chegada_prev    datetime64[ns]
#  6   dt_chegada_real    datetime64[ns]
#  7   situacao           int32
#  8   justificativa      object
#  9   aeroporto_origem   object
#  10  cidade_origem      object
#  11  uf_origem          object
#  12  pais_origem        object
#  13  aeroporto_destino  object
#  14  cidade_destino     object
#  15  uf_destino         object
#  16  pais_destino       object
#  17  long_destino       float64
#  18  lat_destino        float64
#  19  long_origem        float64
#  20  lat_origem         float64
# dtypes: datetime64[ns](4), float64(4), int32(1), object(12)
# memory usage: 397.7+ MB

# %% [markdown]
# ### Quais são as origens mais frequentes?

# %%
# Quantos aeroportos de destino existem?

print("Qtd de registros: ", df['aeroporto_origem'].nunique())

print("Qtd de registros não nulos: ", df[ df['dt_partida_prev'].isnull() == False ]['aeroporto_origem'].nunique())
# Out:
# Qtd de registros:  189
# Qtd de registros não nulos:  189

# %%
df.groupby('aeroporto_origem').agg({'voos': np.count_nonzero}).reset_index().sort_values(by='voos', ascending=False)
# Out:
#                                      aeroporto_origem    voos
# 76        Guarulhos - Governador Andre Franco Montoro  344835
# 145                   Presidente Juscelino Kubitschek  190010
# 49                                          Congonhas  162301
# 3    Aeroporto Internacional Do Rio De Janeiro/Galeao  158571
# 182                                         Viracopos  154737
# ..                                                ...     ...
# 47                                         Cochabamba      51
# 43                                  Cheddi Jagan Intl      45
# 90                                          La Romana      29
# 163                                      Santo Angelo      17
# 85                                        Jericoacara       7
#
# [189 rows x 2 columns]

# %%
df_origem = df.groupby('aeroporto_origem').agg({'voos': np.count_nonzero}).reset_index().sort_values(by='voos', ascending=False)

df_origem.columns = ['origem', 'qtd_voos']

df_origem['perc_voos'] = ((df_origem['qtd_voos'] / df.shape[0] ) * 100 ).round(3)

df_origem['acumulado'] = df_origem['perc_voos'].cumsum()

df_origem.head(20)
# Out:
#                                                origem  qtd_voos  perc_voos  \
# 76        Guarulhos - Governador Andre Franco Montoro    344835     13.563
# 145                   Presidente Juscelino Kubitschek    190010      7.473
# 49                                          Congonhas    162301      6.383
# 3    Aeroporto Internacional Do Rio De Janeiro/Galeao    158571      6.237
# 182                                         Viracopos    154737      6.086
# 172                                    Tancredo Neves    138723      5.456
# 164                                     Santos Dumont     95947      3.774
# 58                    Deputado Luis Eduardo Magalhaes     89312      3.513
# 159                                     Salgado Filho     85470      3.362
# 6                                         Afonso Pena     83567      3.287
# 75                       Guararapes - Gilberto Freyre     78421      3.084
# 135                                     Pinto Martins     60151      2.366
# 180                                       Val De Cans     47195      1.856
# 111                                   Marechal Rondon     42058      1.654
# 160                                    Santa Genoveva     41921      1.649
# 78                                       Hercilio Luz     41096      1.616
# 62                                      Eduardo Gomes     37847      1.489
# 65                            Eurico De Aguiar Salles     37756      1.485
# 94                                        Leite Lopes     26515      1.043
# 72                           Governador Aluizio Alves     25265      0.994
#
#      acumulado
# 76      13.563
# 145     21.036
# 49      27.419
# 3       33.656
# 182     39.742
# 172     45.198
# 164     48.972
# 58      52.485
# 159     55.847
# 6       59.134
# 75      62.218
# 135     64.584
# 180     66.440
# 111     68.094
# 160     69.743
# 78      71.359
# 62      72.848
# 65      74.333
# 94      75.376
# 72      76.370

# %%
ax = sns.barplot(
    data = df_origem.head(20)
    , x = 'qtd_voos'
    , y = 'origem'
)

ax.figure.set_size_inches(6,8)
ax.set_title("Aeroporto de Origem x Quantidade de Voos")
ax.set_xlabel("Quantidade de Voos")
ax.set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ### Quais são os destinos mais frequentes?

# %%
# Quantos aeroportos de destino existem?

print("Qtd de registros: ", df['aeroporto_destino'].nunique())

print("Qtd de registros não nulos: ", df[ df['dt_partida_prev'].isnull() == False ]['aeroporto_destino'].nunique())
# Out:
# Qtd de registros:  189
# Qtd de registros não nulos:  189

# %%
df_destino = df.groupby('aeroporto_destino').agg({'voos': np.count_nonzero}).reset_index().sort_values(by='voos', ascending=False)

df_destino.columns = ['origem', 'qtd_voos']

df_destino['perc_voos'] = ((df_destino['qtd_voos'] / df.shape[0]) * 100 ).round(3)

df_destino['acumulado'] = df_destino['perc_voos'].cumsum()

df_destino.head(20)
# Out:
#                                                origem  qtd_voos  perc_voos  \
# 77        Guarulhos - Governador Andre Franco Montoro    344466     13.548
# 145                   Presidente Juscelino Kubitschek    190469      7.491
# 3    Aeroporto Internacional Do Rio De Janeiro/Galeao    159501      6.273
# 49                                          Congonhas    157124      6.180
# 182                                         Viracopos    154665      6.083
# 172                                    Tancredo Neves    138615      5.452
# 164                                     Santos Dumont     97627      3.840
# 59                    Deputado Luis Eduardo Magalhaes     89161      3.507
# 159                                     Salgado Filho     89070      3.503
# 6                                         Afonso Pena     85839      3.376
# 76                       Guararapes - Gilberto Freyre     78928      3.104
# 135                                     Pinto Martins     60302      2.372
# 180                                       Val De Cans     47732      1.877
# 111                                   Marechal Rondon     41994      1.652
# 160                                    Santa Genoveva     41263      1.623
# 79                                       Hercilio Luz     41137      1.618
# 66                            Eurico De Aguiar Salles     37807      1.487
# 63                                      Eduardo Gomes     37759      1.485
# 95                                        Leite Lopes     26576      1.045
# 73                           Governador Aluizio Alves     24663      0.970
#
#      acumulado
# 77      13.548
# 145     21.039
# 3       27.312
# 49      33.492
# 182     39.575
# 172     45.027
# 164     48.867
# 59      52.374
# 159     55.877
# 6       59.253
# 76      62.357
# 135     64.729
# 180     66.606
# 111     68.258
# 160     69.881
# 79      71.499
# 66      72.986
# 63      74.471
# 95      75.516
# 73      76.486

# %%
ax = sns.barplot(
    data = df_destino.head(20)
    , x = 'qtd_voos'
    , y = 'origem'
)

ax.figure.set_size_inches(6,8)
ax.set_title("Aeroporto de Destino x Quantidade de Voos")
ax.set_xlabel("Quantidade de Voos")
ax.set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
df_origem = df[
    df['aeroporto_origem'] == 'Guarulhos - Governador Andre Franco Montoro' 
].loc[:, ['voos', 'aeroporto_origem', 'aeroporto_destino', 'tp_voo']]

df_origem.head()
# Out:
#           voos                             aeroporto_origem aeroporto_destino  \
# 215  AAL - 234  Guarulhos - Governador Andre Franco Montoro             Miami
# 216  AAL - 234  Guarulhos - Governador Andre Franco Montoro             Miami
# 217  AAL - 234  Guarulhos - Governador Andre Franco Montoro             Miami
# 218  AAL - 234  Guarulhos - Governador Andre Franco Montoro             Miami
# 219  AAL - 234  Guarulhos - Governador Andre Franco Montoro             Miami
#
#             tp_voo
# 215  Internacional
# 216  Internacional
# 217  Internacional
# 218  Internacional
# 219  Internacional

# %%
df_origem.groupby('aeroporto_destino').agg(
    {'voos': np.count_nonzero}).reset_index().sort_values(by='voos', ascending=False).head(6)
# Out:
#                                    aeroporto_destino   voos
# 89                                     Salgado Filho  19074
# 29                   Deputado Luis Eduardo Magalhaes  18759
# 5                                        Afonso Pena  17183
# 38                      Guararapes - Gilberto Freyre  16118
# 98                                    Tancredo Neves  14761
# 2   Aeroporto Internacional Do Rio De Janeiro/Galeao  14038

# %%
df_origem.groupby('aeroporto_destino').agg(
    {'voos': np.count_nonzero}).reset_index().sort_values(by='voos', ascending=False).head(6)['aeroporto_destino'].to_list()
# Out:
# ['Salgado Filho',
#  'Deputado Luis Eduardo Magalhaes',
#  'Afonso Pena',
#  'Guararapes - Gilberto Freyre',
#  'Tancredo Neves',
#  'Aeroporto Internacional Do Rio De Janeiro/Galeao']

# %%
df_origem.groupby('aeroporto_destino').agg(
    {'voos': np.count_nonzero}).reset_index().sort_values(by='voos', ascending=False).head(6)['voos'].to_list()
# Out:
# [19074, 18759, 17183, 16118, 14761, 14038]

# %%
categories = ['Salgado Filho',
 'Deputado Luis E. M.',
 'Afonso Pena',
 'Guararapes',
 'Tancredo Neves', 'Galeão']
categories = [*categories, categories[0]]

restaurant_1 = [19074, 18759, 17183, 16118, 14761, 14038]

restaurant_1 = [*restaurant_1, restaurant_1[0]]


label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(restaurant_1))

plt.figure(figsize=(8, 8))
plt.subplot(polar=True)
plt.plot(label_loc, restaurant_1, label='Aeroportos')

plt.title('TOP 5 Destinos - Guarulhos', size=10, y=1.05)
lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories)
plt.legend("")
plt.show()

# %% [markdown]
# ### Qual é tipo de voo mais utilizado?

# %%
df['tp_voo'].value_counts()
# Out:
# Nacional         1780319
# Regional          441240
# Internacional     320960
# Name: tp_voo, dtype: int64

# %%
df.assign(
    dt=df['dt_partida_prev'].dt.strftime('%Y-%m-%d').astype('datetime64[ns]'), 
    tp=df['tp_voo']
).groupby(['dt', 'tp']).agg({'voos': np.count_nonzero}).reset_index()

ax = sns.lineplot(
    data = df.assign(
        dt=df['dt_partida_prev'].dt.strftime('%Y-%m-%d').astype('datetime64[ns]'), 
        tp=df['tp_voo']).groupby(['dt', 'tp']).agg({'voos': np.count_nonzero}).reset_index(),
    x = 'dt', 
    y = 'voos',
    hue = 'tp',
    marker = 'o'
)
ax.figure.set_size_inches(15,5)

# %%
for tp_nome in ['Internacional', 'Nacional', 'Regional']:
    
    ax = sns.lineplot(
        data = df[ df['tp_voo'] == tp_nome ].assign(
            dt=df['dt_partida_prev'].dt.strftime('%Y-%m-%d').astype('datetime64[ns]'), 
            tp=df['tp_voo']).groupby(['dt', 'tp']).agg({'voos': np.count_nonzero}).reset_index(),
        x = 'dt', 
        y = 'voos',
        hue = 'tp',
        marker = 'o'
    )
    
    ax.figure.set_size_inches(15,5)
    ax.set_title(tp_nome.upper())
    plt.figure()

# %% [markdown]
# ### Existe alguma companhia área que mais de destaca?

# %% [markdown]
# ### Qual é hora que mais tem voos programados?

# %% [markdown]
# ### Expectativa x Realidade - Os voos cumprem o prazo prometido?
